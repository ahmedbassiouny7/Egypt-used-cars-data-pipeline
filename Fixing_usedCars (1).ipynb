# %%
print("here is where we discover our data, and get sone insights")
# Out:
# here is where we discover our data, and get sone insights

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
used = pd.read_csv("/content/hatla2ee_used_cars.csv")
used.head(1)
# Out:
#    page car_type             car_name  year   mileage transmission fuel  \
# 0     1     used  Mercedes C 180 2025  2025  5,000 KM    Automatic  Gas
#
#            price                    location     brand  model  \
# 0  3,300,000 EGP  Tagamo3 - New Cairo, Cairo  Mercedes  C 180
#
#                                              car_url  \
# 0  https://eg.hatla2ee.com/en/car/mercedes/c-180/...
#
#                                            image_url           scraped_at
# 0  https://legion-images.hatla2ee.com/listing_ima...  2026-04-30 14:20:32

# %% [markdown]
# *   drop page num --> done
# *   you may drop car name, as we got the same data in other columns
#
# *   transform price & mileage into numeric column --> done
# *   get more data from location, like city, town. --> done
#
#
# *   drop car_URL --> done
# *   we may keep scrapped at as an indicator for starting the new job.
#
#
# *   fix the nulls in model column --> done
#
# *   extracted the governrate and fixed the nulls in it.
# *

# %%
used.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10173 entries, 0 to 10172
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   page          10173 non-null  int64
#  1   car_type      10173 non-null  object
#  2   car_name      10173 non-null  object
#  3   year          10173 non-null  int64
#  4   mileage       10173 non-null  object
#  5   transmission  10173 non-null  object
#  6   fuel          10173 non-null  object
#  7   price         10173 non-null  object
#  8   location      10173 non-null  object
#  9   brand         10173 non-null  object
#  10  model         10171 non-null  object
#  11  car_url       10173 non-null  object
#  12  image_url     10173 non-null  object
#  13  scraped_at    10173 non-null  object
# dtypes: int64(2), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# *   there are 2 nulls in Model column --> to be fixed

# %%
used[used['model'].isna()]
# Out:
#       page car_type           car_name  year     mileage transmission fuel  \
# 4577   235     used  Nissan Sunny 2015  2015  185,000 KM    Automatic  Gas
# 5886   322     used        BMW X6 2019  2019   90,000 KM    Automatic  Gas
#
#               price location  brand model  \
# 4577    490,000 EGP   Nissan  Sunny   NaN
# 5886  2,800,000 EGP      BMW     X6   NaN
#
#                                                 car_url  \
# 4577  https://eg.hatla2ee.com/en/car/nissan/sunny/71...
# 5886      https://eg.hatla2ee.com/en/car/bmw/x6/7197351
#
#                                               image_url           scraped_at
# 4577  https://legion-images.hatla2ee.com/listing_ima...  2026-04-30 15:36:38
# 5886  https://legion-images.hatla2ee.com/listing_ima...  2026-04-30 16:02:21

# %%
# fixing the nulls in model column

used.loc[4577 , 'model'] = "Sunny"
used.loc[4577 , 'brand'] = "Nissan"
used.loc[4577 , 'location'] = ""

# %%
used[used['model'].isna()]
# Out:
#       page car_type     car_name  year    mileage transmission fuel  \
# 5886   322     used  BMW X6 2019  2019  90,000 KM    Automatic  Gas
#
#               price location brand model  \
# 5886  2,800,000 EGP      BMW    X6   NaN
#
#                                             car_url  \
# 5886  https://eg.hatla2ee.com/en/car/bmw/x6/7197351
#
#                                               image_url           scraped_at
# 5886  https://legion-images.hatla2ee.com/listing_ima...  2026-04-30 16:02:21

# %%
used.loc[5886 , 'model'] = "X6"
used.loc[4577 , 'brand'] = "BMW"
used.loc[4577 , 'location'] = ""

# %%
used.drop(columns = ["page", "car_url", "image_url"] , inplace = True)

# %%
used.head(2)
# Out:
#   car_type             car_name  year     mileage transmission fuel  \
# 0     used  Mercedes C 180 2025  2025    5,000 KM    Automatic  Gas
# 1     used        BMW X5 M 2015  2015  180,000 KM    Automatic  Gas
#
#            price                    location     brand  model  \
# 0  3,300,000 EGP  Tagamo3 - New Cairo, Cairo  Mercedes  C 180
# 1  1,750,000 EGP     Sheikh Zayed City, Giza       BMW   X5 M
#
#             scraped_at
# 0  2026-04-30 14:20:32
# 1  2026-04-30 14:20:34

# %%
# transform the columns "price" & "mileage"

# %%
used["price"] = pd.to_numeric(used["price"].str.replace(r"\D", "", regex=True))
used["mileage"] = pd.to_numeric(used["mileage"].str.replace(r"\D", "", regex=True))

# %%
#used.info()

# %%
# dealing with location
used["location"]
# Out:
# 0        Tagamo3 - New Cairo, Cairo
# 1           Sheikh Zayed City, Giza
# 2                 Heliopolis, Cairo
# 3           Sheikh Zayed City, Giza
# 4           Sheikh Zayed City, Giza
#                     ...
# 10168                         Cairo
# 10169                         Cairo
# 10170             Obour City, Cairo
# 10171                         Cairo
# 10172             Heliopolis, Cairo
# Name: location, Length: 10173, dtype: object

# %%
import re
import pandas as pd

gov_aliases = {
    "cairo": ["cairo"],
    "giza": ["giza", "6th of october", "october", "sheikh zayed"],
    "alex": ["alex", "alexandria"],
    "dakahlia": ["dakahlia", "mansoura"],
    "red sea": ["red sea", "hurghada"],
    "beheira": ["beheira", "damanhur"],
    "fayoum": ["fayoum"],
    "gharbia": ["gharbia", "tanta"],
    "ismailia": ["ismailia"],
    "monufia": ["monufia", "shebin el kom"],
    "minya": ["minya"],
    "qalyubia": ["qalyubia", "benha"],
    "new valley": ["new valley"],
    "suez": ["suez"],
    "aswan": ["aswan"],
    "assiut": ["assiut"],
    "beni suef": ["beni suef"],
    "port said": ["port said"],
    "damietta": ["damietta"],
    "sharkia": ["sharkia", "zagazig"],
    "south sinai": ["south sinai", "sharm"],
    "kafr el sheikh": ["kafr el sheikh"],
    "matrouh": ["matrouh"],
    "luxor": ["luxor"],
    "qena": ["qena"],
    "north sinai": ["north sinai"],
    "sohag": ["sohag"]
}

# %%
def merge_aliases(base, new):
    for key, values in new.items():
        if key in base:
            base[key] = list(set(base[key] + values))  # merge + deduplicate
        else:
            base[key] = values
    return base

# %%
new_aliases = {
    "assiut": ["assyut", "asyut", "assiut"],
    "sharkia": ["sharqia", "sharkia", "faqous", "bilbeis", "abu kabir", "dyarb negm"],
    "fayoum": ["faiyum", "fayoum", "el faiyum"],
    "beni suef": ["beni suef", "ben suef"],
    "new valley": ["el wadi el gedid", "wadi gedid", "kharga", "farafra"],
    "aswan": ["kom ombo"],
    "matrouh": ["mariotya"],
    "sinai": ["sinai"],
    "monufia": ["menofia", "ashmun", "birkat as sab" , "Monufia" ,"Shibin el Kom" , "El Bagour", "Tala" , "Ashmoun" , "Quwaysna"]
}

gov_aliases = merge_aliases(gov_aliases, new_aliases)

# %%
used.head(2)
# Out:
#   car_type             car_name  year  mileage transmission fuel    price  \
# 0     used  Mercedes C 180 2025  2025     5000    Automatic  Gas  3300000
# 1     used        BMW X5 M 2015  2015   180000    Automatic  Gas  1750000
#
#                      location     brand  model           scraped_at
# 0  Tagamo3 - New Cairo, Cairo  Mercedes  C 180  2026-04-30 14:20:32
# 1     Sheikh Zayed City, Giza       BMW   X5 M  2026-04-30 14:20:34

# %%
#used.info()

# %%
#used.loc[used["city"].isna(), "location"].unique()

# %%
def normalize(text):
    text = str(text).lower().strip()
    text = re.sub(r"[^\w\s]", " ", text)
    text = re.sub(r"\s+", " ", text)
    return text

# %%
def extract_governorate_and_city(location):
    if pd.isna(location) or str(location).strip() == "":
        return None, None

    loc = normalize(location)

    best_match = None
    best_gov = None

    # prioritize longest match
    for gov, aliases in gov_aliases.items():
        for alias in sorted(aliases, key=len, reverse=True):
            if alias in loc:
                best_match = alias
                best_gov = gov
                break
        if best_match:
            break

    if best_match:
        city = loc.replace(best_match, "").strip()
        return best_gov, (city if city else None)

    # fallback → treat whole thing as city
    return None, loc

# %%
used[["governorate", "city"]] = used["location"].apply(
    lambda x: pd.Series(extract_governorate_and_city(x))
)

# %%
used.head(2)
# Out:
#   car_type             car_name  year  mileage transmission fuel    price  \
# 0     used  Mercedes C 180 2025  2025     5000    Automatic  Gas  3300000
# 1     used        BMW X5 M 2015  2015   180000    Automatic  Gas  1750000
#
#                      location     brand  model           scraped_at  \
# 0  Tagamo3 - New Cairo, Cairo  Mercedes  C 180  2026-04-30 14:20:32
# 1     Sheikh Zayed City, Giza       BMW   X5 M  2026-04-30 14:20:34
#
#   governorate         city
# 0       cairo  tagamo3 new
# 1        giza    city giza

# %%
#used.info()

# %%
used.loc[used["governorate"].isna(), "location"].unique()
# Out:
# array(['', 'BMW', '5th Settlement'], dtype=object)

# %%
used['model'].unique()
# Out:
# array(['C 180', 'X5 M', 'EcoSport', 'Z4', 'GLA 200', 'Lanos 2', 'M11',
#        'Astra', 'Prado', 'Matrix', 'Logan', 'Tiggo 3', 'Sunny',
#        'Accent RB', '200', 'Grand Cherokee', '318', '911', 'Viano',
#        'Lanos', 'X3', '320i', '218 i', 'Sportage', '320', 'X6', 'Cerato',
#        'S 500', 'Other', 'N-Series', 'Corolla', 'Galena', '330S',
#        'Terios', 'Accent', 'Megane', 'Focus', '5', 'Qashqai', 'Alto',
#        '520', 'Sandero', 'Civic', 'Lancer EX Shark', 'Lancer', 'Arona',
#        'Venucia Star', 'F3', 'E 180', 'Kadjar', 'Crossland', 'CLA 200',
#        'A4', 'F-Type', 'Range Rover Sport', 'E 350', 'Country man',
#        'Velar', 'A 200', 'E 300', 'Elantra', 'A113', 'Golf 4', 'Avante',
#        'Range Rover Vogue', 'Ibiza', 'C260L', 'Octavia', 'Passat',
#        'Grandland', 'GLE 450', 'Nubira 2', 'Wrangler', 'Optra',
#        'E 53 AMG', 'Fiesta', '929', 'Vectra', 'Challenger', 'C 200',
#        '5008', '6', 'F-Pace', 'Carens', 'Tiggo 7', 'X4', 'Cayenne S',
#        'E 250', 'S60', 'Fluence', 'GLC 300', 'FSV', 'D max', 'X1', 'S2',
#        'E 200', 'Altea', 'Nubira', 'Insignia', 'Rx5', 'Leon',
#        'Cerato Koup', 'Picanto', 'Tucson', 'C4X', 'Outlander', 'Toledo',
#        'Materia', 'Saipa', 'HS', 'C4', 'A3', 'Cherokee', 'Swift Dzire',
#        'Arrizo 5', 'Liberty', 'N300', 'Macan', '307 SW', 'GLS',
#        'Elantra HD', 'Wrangler Rubicon', 'Tiguan', 'BJ30', 'Tipo', 'Niva',
#        'Pajero', 'Torres', '3008', 'Fortuner', 'Kodiaq', 'Altea XL',
#        'Tucson GDI', 'Scenic', 'Octavia A7', 'Xsara', 'Sandero Step Way',
#        'S 450', 'Model X', 'A 180', '131', 'Favorit', 'XTrail', '250',
#        'Sephia', 'Siena', 'Mk', '127', 'C5 Aircross', 'XC90', '206',
#        'Z4 M40', 'Octavia A8', 'XC60', 'C 280', 'C 250', 'Sentra',
#        'Grand i10', 'Mondeo', 'Cool Ray', 'X5', 'C3', '525', '128',
#        'ID 6', 'Range Rover Evoque', 'Verna', 'Carnival', 'X7', 'GLC 200',
#        'Aveo', 'X70S', 'Xceed', 'Impreza', 'Superb', 'Bolt', 'Granta',
#        '132', '405', 'Range Rover Sport SVR', 'XV', 'Attrage',
#        'Grand vitara', 'Logan MCV', 'Wira', '740', 'Veloster', 'G6',
#        'Swift', '3', 'Grand Punto', 'E 200 AMG', 'Sorento', 'Corsa', 'J7',
#        'Mokka', 'Other Model', 'Kona', 'Bayon', 'Elantra CN7', 'J2',
#        'Envy', 'TT', 'CLE 200', 'Camaro', 'Countryman S', 'Cooper',
#        'Emgrand 7', 'Renegade', 'Boxster', 'S580', 'Cooper Paceman',
#        '508', 'Lancer Crystala', 'Clio', 'Xplosion', 'Juke', 'Spark',
#        'Q8', 'C 300', 'Defender', 'A516', 'IX 35', 'Golf 7', 'Model Y',
#        'C4 Grand Picasso', 'Fantasia', 'Tiggo', 'Land Cruiser', 'K4',
#        'Elantra AD', 'Maruti', 'Gen 2', '308', 'K3', 'Nubira 1', 'Hilux',
#        'X40', 'Lancer Puma', 'C3 Aircross', 'Ceed', 'CC', 'X25', '2017',
#        'Terramar', 'Giulia', '530', 'X70 Plus', 'A5', '116', 'Dogan',
#        'V5', 'Atos', '408', '430', 'City', 'Solaris', 'CLS Class',
#        'Leganza', 'Emgrand X7', 'One', 'RX5 Plus', 'X4M', 'EQS 500',
#        'foison', 'Celerio', 'Duster', '218', 'G63', 'C-HR', 'B 200', 'Q3',
#        '301', 'Rio', 'C Elysee', 'L3', 'Model 3', 'Eclipse', 'Azera',
#        'Xpander', 'Rapid', 'Dokker', '316', '2107', 'Ciaz', '330',
#        'Yaris', 'H100', 'EC7', '2', 'CLA 180', 'Captur', 'Vantage',
#        'Tiggo 8', '2008', 'CS 35', 'I5', 'Captiva', 'T2', 'Jimny',
#        'Foreman', 'Elantra MD', 'EAGLE 580', 'Cruze', '500 X', 'Patrol',
#        'Preve', 'Legacy', 'A11', 'Regata', 'Octavia A5', 'Q7', 'Kushaq',
#        'GLC 43', 'Kamiq', '323', 'Jetta', 'Pacifica', 'Range Rover', 'C5',
#        'X2', 'Polo', 'Shahin', 'DS7', '745', '128 Nova', 'Eclipse Cross',
#        'ZS', 'A620', 'Punto', 'Tivoli', 'John Cooper', 'Octavia A4',
#        'A213', 'Felicia', 'Fusion', 'Bentayga', 'FRV', 'A6', 'Beetle',
#        '406', '118', 'Taycan', 'Scala', 'Austral', 'Meriva', 'GL Class',
#        'Lr4', 'Tiida', 'Carrera', 'Getz', 'Tarraco', 'S350', 'T600',
#        '530 E', 'Soul', 'S 320', 'Linea', 'Santamo', 'I20', '7', '500',
#        'Dart', 'Shuma', 'Creta', '420', 'Golf R', 'Charger', 'Polonez',
#        'Rainbow', '1100', 'Pride', 'Accent HCI', '535', 'K01', 'Juliet',
#        'Pandino', 'JS3', 'Accord', 'CLE 300', 'X95', 'EQ7', 'Emgrand',
#        'E 240', 'GLK 250', 'Tucson Turbo GDI', 'Pride Sedan',
#        'Cybertruck', 'X3 M', 'IX3', 'Albea', '340', 'CS 15', 'Alsvin',
#        '230', '9.0', '147', 'S Presso', '19', 'Pickup', 'I30',
#        'Tiggo 4 Pro', 'Ghibli', '300', '528', 'E-pace', '335', 'Ateca',
#        'Escalade', 'Sonata', 'Ax', 'I10', 'Saga', 'C30', '2111', 'Jolion',
#        'Lacetti', 'Sealion 6', '180', 'Elantra Coupe', '523', 'IX1',
#        'U5 plus', 'Rush', 'E 230', 'Uno', 'M3', 'M5', 'Sportage L', '207',
#        'ID 4', 'C4 Picasso', 'Panda', 'Empow', 'Tempra', 'Forte',
#        'Bronco Raptor', '07', 'Emira', 'M850', 'Armada', 'GLE',
#        'Galloper', 'GLK', 'Splendor', 'B 180', 'Voyager', 'V 250', '11',
#        '001', 'Q35', 'Tiba', 'Colt', 'T1', 'Belta', 'Cressida', 'Lyriq',
#        'Van', 'Seltos', '450', 'A 35 AMG', 'Touareg', 'K5', 'GLC 250',
#        'T5 evo', 'SIRION', '504', 'ideal', 'Pointer', 'Continental GT',
#        'Emkoo', 'Golf 6', 'Pegas', 'Dedra', 'Bora', 'Suran', 'X55',
#        'Caravelle', 'X6 M', 'Panamera', 'Song L', 'Model S', '307', 'GT',
#        'Bravo', 'Everest', 'C300', 'Grand Cherokee L',
#        'Grand C4 Spacetourer', 'Grand terios', 'Tivoli XLV',
#        'Grand Cerato', 'B70', 'S 06', 'EC 7', 'S 400', 'Compass', 'Ds5',
#        'T-Series', 'Benni', 'Grandis', 'Avanza', 'H6', 'Kuga', 'Cascada',
#        'Urban Cruiser', 'Santa Fe', 'Carnival MPV', 'Excel', 'EQB 350',
#        'Hummer EV', 'EQS 450', 'Vitara', 'Coupe', 'Jumpy', 'Urus', 'I7',
#        'EQA 260', '3 Series', 'Q22', 'Nativa', '1 Series', 'Formentor',
#        'N200', 'Viva', 'UNI-T', '156', 'Rapid Spaceback',
#        'Tiggo 7 pro max', 'Golf 2', 'Petra', 'S5', 'XE', 'Fruits', 'S3',
#        'Equinox', 'Matiz', 'Other Make DFM', 'Ertiga', 'Charade', 'M12',
#        'Macan Electric', 'I3', '01', 'Leopard 3', '730', 'Maybach GLS',
#        'Pick up', 'GLK 350', 'G Class', 'Fabia', '2105', 'Golf 3', 'A15',
#        '208', 'Kalina', 'Turan', 'RS5', 'Maybach', 'GLC', 'Kardian',
#        'Q5 E-Tron', 'EQE 350', 'EQS 580', 'Cayman', 'Corvette',
#        'Tiggo 7 pro', '280', 'Leopard 8', 'EQS 450+', 'EQE 300', 'Taos',
#        'X70', 'Arrizo 6', 'GLK 300', 'Scorpio', 'Escort', '190', 'B 150',
#        'S 560', '12', 'CLA 45 AMG', 'New Star', 'Samara', '308 sw', '407',
#        'Golf 5', 'Benni mini', 'Town & Country', 'Cooper F55', 'M70',
#        'S 05', 'Punto evo', 'C63 AMG', 'Mirage', 'FRV Cross', '505',
#        'E 280', '518', 'Avensis', 'Corona', 'Taliant', '126', 'Camry',
#        'Komodo', 'Bluebird', 'Outlander Sport', 'Giulietta', 'GT 43',
#        'Lx', 'Cielo', 'mercury', 'Centennial', 'Pilot', 'Vita', 'E-HS9',
#        'S 280', 'EON', 'A1', 'Discovery sport', 'DB11', '850', 'Q',
#        'Sparky', 'Spectra', 'Terrain', 'ZRV', 'Waja', 'C40', 'XC 40',
#        'S 09', 'C 200 AMG', 'H6 HEV', 'Chery QQ', '125', 'Auris', 'Echo',
#        'Gran Coupe', 'Tercel', 'EQV 300', 'Eos', 'Felicia combi',
#        'Espero', 'Ram', 'Tiggo 8 Pro', 'Stelvio', 'Transporter', 'I4',
#        'CS55 Plus', 'Sprint', 'F0', 'Discovery', 'Okavango', 'Malibu',
#        'M4', 'Eado', '1200', 'Kicks', '16', 'GLC300 AMG', 'Palio', 'Q5',
#        'C 230', 'Trax', 'Gazelle', 'Exora', 'Alpha s5', '124', 'A7',
#        'T77 Pro', 'GLC 200 AMG Imported', 'Berlingo', 'Familia', 'S-Type',
#        'Veryca', 'B-Max', 'Mito', 'G9', 'GX3 Pro', 'ENS1', 'Zaz', 'DS5',
#        '440i', 'HRV', 'Tonale', 'E 320', 'Mini Cooper S', 'S40', 'P7',
#        '718', 'Dashing', 'Marea', 'X90 Plus', 'Starray', 'Gol', 'SU7',
#        'Cordoba', 'CRV', 'Song Plus', 'Golf 8', 'A30 Shine', 'E 220',
#        'Laguna', 'Doblo', 'A 150', 'Huge', 'Parati', 'S1', 'Aeolus A30',
#        'Flying Spur', 'ID7', 'ID3', 'Outback', 'Galant', 'Gran max',
#        'Baleno', 'Haima 2', 'Golf', 'Grand Santa Fe', '305', 'V60',
#        'Persona', 'Ami', 'DX3', '121', 'Adam', 'Symbol', 'Fox', 'Livina',
#        'A 10', 'New Carrying', '2101', 'Ck2', 'Eagle pro', 'Pony',
#        'Prius', '205', 'Territory', 'Explorer', 'E2', 'K07S', '1300',
#        'S 350', 'Florid', 'New Boarding', 'DS3', 'Trooper', 'IX',
#        'X 70 FL', 'CS 35 Plus', 'EQE 500', 'Scirocco', 'Range Rover SVR',
#        'Almera', 'Leon Sportstourer', 'T5', '232', '207 SW', 'Sokon',
#        'Partner', 'Wrangler 4xe', 'Ritmo', 'Z100', 'T500', 'H1',
#        'GLA 180', 'XJ8', 'T-Roc', 'Musa', 'Terrano', 'Imperial', '240',
#        'B 160', 'Spark Lite', '7X', 'Expedition', 'CLA 45 S', '418',
#        'Rumion', 'Wrangler Unlimited', 'Patrol safari', 'S80', 'SLK 300',
#        'A 140', '1500', '2110', 'Glory 330', 'MZ 40', 'Rodeo', '328',
#        'Neon', 'JS4', '21', '735', 'XJ', 'Tiggo 4', 'Actyon Sport',
#        'Trial Blazer', 'Navigator', 'S7', '86', 'Florida', 'ZX', '750',
#        'L 200', '133', 'Navara', 'Rav 4', 'Lodgy', 'GR Corolla',
#        'Cayenne', 'Ck', 'Caddy', 'Ex 7', 'Optima', 'X35', 'Applause',
#        'M1', 'V6', 'Montero', 'GLE 500', '9', 'Family', 'PT Cruiser',
#        'Manza', 'Octavia Combi', 'X Pandino', 'Clarus', 'Kancil',
#        'Blazer', 'B15', 'SR7', 'Grand cherokee 4xe', 'Clubman', 'Carry',
#        'Tiggo 8 Pro Max'], dtype=object)

# %%
print(used['price'].min() , used['price'].max())
# Out:
# 1 111111111111

# %%
used['price']
# Out:
# 0        3300000
# 1        1750000
# 2         850000
# 3        3700000
# 4        2000000
#           ...
# 10168     550000
# 10169     300000
# 10170     350000
# 10171    1250000
# 10172     330000
# Name: price, Length: 10173, dtype: int64

# %%
# Step 1: Define valid prices
valid_prices = used["price"] >= 100000

# Step 2: Compute averages
model_avg = used[valid_prices].groupby("model")["price"].mean()
manufacturer_avg = used[valid_prices].groupby("brand")["price"].mean()
global_avg = used.loc[valid_prices, "price"].mean()

# Step 3: Map averages
used["model_avg"] = used["model"].map(model_avg)
used["manufacturer_avg"] = used["brand"].map(manufacturer_avg)

# Step 4: Replace invalid prices using hierarchy
used["price"] = used["price"].where(
    valid_prices,
    used["model_avg"]
)

# Step 5: Fill remaining NaNs (models with no valid prices)
used["price"].fillna(used["manufacturer_avg"], inplace=True)

# Step 6: Final fallback (manufacturers with no valid prices)
used["price"].fillna(global_avg, inplace=True)

# Step 7: Cleanup
used.drop(columns=["model_avg", "manufacturer_avg"], inplace=True)
# Out:
# /tmp/ipykernel_12328/303237642.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   used["price"].fillna(used["manufacturer_avg"], inplace=True)
# /tmp/ipykernel_12328/303237642.py:23: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   used["price"].fillna(global_avg, inplace=True)

# %%
used["price"].isna().sum()
# Out:
# np.int64(0)

# %%
print(used['price'].min() , used['price'].max())
# Out:
# 100000.0 111111111111.0
